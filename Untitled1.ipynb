# %% [markdown]
# <a href="https://colab.research.google.com/github/lluvia23/unidad-3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# conseptos basicos de la libreria matplotlib
# --------------
# es una libreria de trazado de grafico de bajo nivel en python que sirve como una herramienta de visualizacion
# matplotlib es de codigo abierto y podemos utilizarlo libremente matplotlib esta escrito principalmente en python con algunos segmentos escritos en C

# %% [markdown]
# instalacion de matplotlib
# -------------
#
# si tienes python y pip ya instalado en tu sistema usando el siguiente comando

# %%
pip install Matplotlib

# %% [markdown]
# desde la linea de comandos

# %% [markdown]
# importar matplotlib
#
# una vez instalado matplotlib importalo en tus aplicaciones agregando el modulo import
# ejemplo:

# %%
import matplotlib

# %% [markdown]
# matplotlib pyplot
#
# pyplot se encuentra dentro del submodulo pyplot y normalmente se importan bajo el alias plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ahora el paquete pyplot puede denominarse plt
